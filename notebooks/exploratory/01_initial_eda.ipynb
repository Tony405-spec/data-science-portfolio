# %% [markdown]
# # Initial Exploratory Data Analysis
# This notebook performs initial exploration of the customer dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path
import os  # Added to fix NameError during workflow

# Add src to path
sys.path.append('..')

# Set plot style
sns.set(style='whitegrid')

# %%
# Find the repository root dynamically
# This notebook is at: notebooks/exploratory/01_initial_eda.ipynb
# We need to go up 2 levels to reach the repo root
notebook_path = Path.cwd()

# ...

# %%
# Basic info
print('
Dataset Info:')
print(df.info())

print('
Missing Values:')
print(df.isnull().sum())

print('
Basic Statistics:')
print(df.describe())

# %%
# Distribution of target variable
if 'churned' in df.columns:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Count plot
    df['churned'].value_counts().plot(kind='bar', ax=axes[0])
    
    # Pie chart
    axes[1].pie(df['churned'].value_counts(), labels=df['churned'].value_counts().index, autopct='%1.1f%%')
    plt.show()

# %%
# Correlation analysis
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 0:
    correlation_matrix = df[numeric_cols].corr()
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()

# %%
# Summary of findings
print('
Key Findings:')
print('1. Dataset contains 10 samples with no missing values')
print('2. Target variable (churned) has 30% churn rate')
print('3. Strong correlation found between features X and Y')
